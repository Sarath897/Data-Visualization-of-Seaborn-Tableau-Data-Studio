# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Placement.csv')
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
# Number of rows and Columns 
print("The Number of Row:",dataset.shape[0])
print("The Number of Column",dataset.shape[1])
# Out:
# The Number of Row: 215
# The Number of Column 15

# %%
dataset.shape
# Out:
# (215, 15)

# %% [markdown]
# # Univarite Analysis

# %%
import seaborn as sb
sb.distplot(dataset['ssc_p'],hist=True,kde=True,kde_kws={'color':'red'})

# %% [markdown]
# # Bivarite Analysis : Distribution Plot

# %%
sb.jointplot(x = 'ssc_p',y = 'salary',data = dataset)
plt.show()

# %% [markdown]
# # jointplot

# %% [markdown]
# # Jointplot Is the main function In Python visualisation library its used to find the relations between the 2 variable
#
#
# A joint plot is a versatile visualization tool from the Seaborn library in Python. It combines two types of plots into a single figure to help you explore the relationship between two variables—for example, height vs. weight or age vs. income.
#
# - The main plot (usually a scatter plot) shows how the two variables relate to each other.
#
# - The side plots display the individual distributions of each variable—typically as histograms or KDE curves.
#
# - Scatter Plot: Displays data points to show correlation
# - Hex Plot: Uses hexagonal bins to show density
# - Contour Plot: Shows smooth density contours for continuous data
# - x & y: variables to compare

# %%
sb.jointplot(x = 'ssc_p',y = 'salary',data = dataset,kind='hex')
plt.show()

# %%
sb.jointplot(x = 'ssc_p',y = 'salary',data = dataset,kind='kde')
plt.show()

# %%
# Pair Plot

# %%
sb.pairplot(dataset,hue = 'gender',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %% [markdown]
# # For Categorical Plot

# %%
sb.stripplot(x = "ssc_b", y = "ssc_p", data = dataset)
plt.show()

# %%
sb.stripplot(x = "gender", y = "ssc_p", data = dataset,jitter=True)
plt.show()

# %%
sb.swarmplot(x = "gender", y = "ssc_p", data = dataset)
plt.show()

# %% [markdown]
# # Distribution Observation

# %%
sb.violinplot(x = "gender", y = "ssc_p", data = dataset)
plt.show()

# %%
sb.violinplot(x = "gender", y = "ssc_p", data = dataset,hue="gender")
plt.show()

# %%
sb.violinplot(x = "specialisation", y = "salary", data = dataset,hue="gender")
plt.show()

# %%
#box plot like Percentile type in plot

sb.boxplot(x = "ssc_b", y = "ssc_p", data = dataset )
plt.show()

# %%
sb.boxplot(x = "ssc_b", y = "ssc_p", data = dataset,hue="gender" )
plt.show()

# %%
# Bar Plot

# %%
sb.barplot(x = "ssc_b", y = "ssc_p", data = dataset,hue='gender')
plt.show()

# %%
sb.countplot(x = "ssc_b",data = dataset,hue='gender');
plt.show()

# %% [markdown]
# # pointplot

# %% [markdown]
# # Plots points representing the mean of a variable for each category
# # Connects those points with lines to show trends
# - Point plot is a type of categorical visualization that displays the mean of  numeric variable for each category using distinct points.It’s commonly used to compare multiple groups across one or more categorical variables.

# %%
sb.pointplot(x = "ssc_p",y="hsc_b",data =dataset,hue='gender')
plt.show()

# %%
sb.boxplot(data = dataset, orient = "h")
plt.show()

# %% [markdown]
# #         Factorplot

# %% [markdown]
# - factorplot was a high-level plotting function in Seaborn used to visualize categorical data. It allowed you to quickly generate plots like bar charts, box plots, and point plots based on categorical groupings.
# - However, in newer versions of Seaborn, factorplot has been deprecated and replaced by catplot, which offers the same functionality with more flexibility

# %% [markdown]
# # Factor
# - In statistics, a factor is a categorical variable. So factorplot was designed to show how a numeric variable changes across different categories (factors)

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('exercise')
sb.factorplot(x = "time", y = "pulse", hue = "kind", kind = 'violin', col = "diet", data = df);
plt.show()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('tips')
sb.regplot(x = "total_bill", y = "tip", data = df)
sb.lmplot(x = "total_bill", y = "tip", data = df)
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('anscombe')
sb.lmplot(x = "x", y = "y", data = df.query("dataset == 'II'"))
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('anscombe')
sb.lmplot(x = "x", y = "y", data = df.query("dataset == 'II'"),order = 2)
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('tips')
g = sb.FacetGrid(df, col = "time")
g.map(plt.hist, "tip")
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
g = sb.PairGrid(df)
g.map(plt.scatter);
plt.show()
